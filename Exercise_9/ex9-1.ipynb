# %% [markdown]
# ## Exercise 9-1: Descriptive Analysis

# %%
import pandas as pd

file_path = 'Session-Summary-all-2025-S1.csv'

try:
    # Try reading with utf-8 encoding
    df = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    # If utf-8 fails, try with a different encoding like latin-1
    df = pd.read_csv(file_path, encoding='latin-1')

print(df.describe(include='all'))
# Out:
#              Timestamp       RollNo Topic  \
# count             2548  2548.000000  2548
# unique            2468          NaN  2131
# top     08-01-25 23:58          NaN   SQL
# freq                 4          NaN    16
# mean               NaN   102.606358   NaN
# std                NaN    55.039652   NaN
# min                NaN     1.000000   NaN
# 25%                NaN    55.000000   NaN
# 50%                NaN   105.500000   NaN
# 75%                NaN   149.000000   NaN
# max                NaN   198.000000   NaN
#
#                                              YourAnalysis
# count                                                2548
# unique                                               2541
# top     In todayâs class, we looked at color process...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
